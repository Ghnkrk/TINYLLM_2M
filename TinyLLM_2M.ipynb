# %%
# !git clone https://github.com/Ghnkrk/TINYLLM_2M
cd TINYLLM_2M

# %%
# !pip install -r TINYLLM/requirements.txt

# %%
# !python TINYLLM/tokenizer/train_tokenizer.py
# Out:
# 🔤 Training SentencePiece tokenizer
# Dataset      : tinystories
# Vocab size   : 4000
# Save prefix  : /content/TINYLLM/tokenizer/tinystories_sp
#
# data/validation-00000-of-00001-869c898b5(…): 100% 9.99M/9.99M [00:01<00:00, 5.47MB/s]
# Generating train split: 100% 2119719/2119719 [00:10<00:00, 204143.62 examples/s]
# Generating validation split: 100% 21990/21990 [00:00<00:00, 176874.73 examples/s]
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/TINYLLM/tokenizer/corpus.txt
#   input_format:
#   model_prefix: /content/TINYLLM/tokenizer/tinystories_sp
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
# ...

# %%
# !python param_count.py
# Out:
# 📊 Model Parameter Summary
# -------------------------
# Experiment      : tinylm_2m
# Vocab size      : 4000
# Total params    : 2,747,296 (2.75M)
# Trainable params: 2,747,296 (2.75M)

# %%
# !python train.py
# Out:
# 🚀 Using device: cuda
#
# Enter your Weights & Biases API key:
# wandb: Currently logged in as: guhan-karthik25 (guhan-karthik25-kumaraguru-college-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 8mgegz96 (0.1s)
# wandb: ⣽ setting up run 8mgegz96 (0.1s)
# wandb: ⣾ setting up run 8mgegz96 (0.1s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/TINYLLM/wandb/run-20251213_152751-8mgegz96
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run tinylm_2m
# wandb: ⭐️ View project at https://wandb.ai/guhan-karthik25-kumaraguru-college-of-technology/TinyLLM
# wandb: 🚀 View run at https://wandb.ai/guhan-karthik25-kumaraguru-college-of-technology/TinyLLM/runs/8mgegz96
# Tokenizer vocab size: 4000
# Train samples: 844977 | Val samples: 17244
# Model parameters: 2.75M
# ...

# %%
# !python inference.py --prompt "On a long distant land" --max_new_tokens 256 --temperature 1.0 --top_k 40 --top_p 0.9 --repetition_penalty 1.2
# Out:
# 🚀 Inference on tinylm_2m (cuda)
#
# ...
